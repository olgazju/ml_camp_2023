# %%
# !pip install lyricsgenius
# Out:
# Collecting lyricsgenius
#   Downloading lyricsgenius-3.0.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 493.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from lyricsgenius) (4.12.2)
# Requirement already satisfied: requests>=2.20.0 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from lyricsgenius) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from beautifulsoup4>=4.6.0->lyricsgenius) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from requests>=2.20.0->lyricsgenius) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from requests>=2.20.0->lyricsgenius) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from requests>=2.20.0->lyricsgenius) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/olgabraginskaya/.pyenv/versions/3.11.4/envs/ml_camp/lib/python3.11/site-packages (from requests>=2.20.0->lyricsgenius) (2023.7.22)
# Installing collected packages: lyricsgenius
# Successfully installed lyricsgenius-3.0.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from lyricsgenius import Genius

genius = Genius('GLE1vGN_OAK1H8wZpZn2qAAGCo0Q35qeFt5jb3fDuBjK-fI3QPOt7ZNJITcaSkGv')
#artist = genius.search_artist('Taylor Swift', max_songs=3, sort="title")
#print(artist.songs)

albums = ["Lover", "folklore", "evermore", 'Midnights']
album = genius.search_album("Maroon", "Taylor Swift")

#album.save_lyrics()
# Out:
# Searching for "Maroon" by Taylor Swift...
# No results found for: 'Maroon Taylor Swift'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/olgabraginskaya/ml_camp_2023/capstione_project_1/notebooks/scrapper.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell:/Users/olgabraginskaya/ml_camp_2023/capstione_project_1/notebooks/scrapper.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> #artist = genius.search_artist('Taylor Swift', max_songs=3, sort="title")
#       <a href='vscode-notebook-cell:/Users/olgabraginskaya/ml_camp_2023/capstione_project_1/notebooks/scrapper.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> #print(artist.songs)
#       <a href='vscode-notebook-cell:/Users/olgabraginskaya/ml_camp_2023/capstione_project_1/notebooks/scrapper.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> album = genius.search_album("Maroon", "Taylor Swift")
# ----> <a href='vscode-notebook-cell:/Users/olgabraginskaya/ml_camp_2023/capstione_project_1/notebooks/scrapper.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> album.save_lyrics()
#
# AttributeError: 'NoneType' object has no attribute 'save_lyrics'

# %%
for track in album.tracks:
    print(track.song.title)
# Out:
# ​willow
# ​champagne problems
# ​gold rush
# ​’tis the damn season
# ​tolerate it
# ​no body, no crime
# ​happiness
# ​dorothea
# ​coney island
# ​ivy
# ​cowboy like me
# ​l​ong story short
# ​marjorie
# ​closure
# ​evermore

# %%
song1 = genius.search_song("Maroon", "Taylor Swift")
#song = artist.song("To You")

print(song1.lyrics)
# Out:
]\nWait for the signal, and I'll meet you after dark\nShow me the places where the others gave you scars\nNow this is an open-shut case\nI guess I should've known from the look on your face\nEvery bait-and-switch was a work of art\n\n[Chorus]\nThe more that you say, the less I know\nWherever you stray, I follow\nI'm begging for you to take my hand\nWreck my plans, that's my man\nYou know that my train could take you home\nAnywhere else is hollow\nI'm begging for you to take my hand\nWreck my plans, that's my man\nThe more that you say, the less I know\nWherever you stray, I follow\nI'm begging for you to take my hand\nWreck my plans, that's my man\nYou know that my train could take you home\nAnywhere else is hollow\nI'm begging for you to take my hand\nWreck my plans, that's my man\n[Outro]\nHey, that's my man\nThat's my man\nYeah, that's my man\nEvery bait-and-switch was a work of art\nThat's my man\nHey, that's my man\nI'm begging for you to take my hand\nWreck my plans, that's my man109Embed"

# %%
import re
# Python code to process the string as described
def process_string1(input_string):
    # Cut the beginning of the string till "Lyrics[Verse 1]\n"
    start_phrase = "Lyrics[Verse 1]\n"
    start_index = input_string.find(start_phrase)
    if start_index != -1:
        processed_string = input_string[start_index + len(start_phrase):]
    else:
        processed_string = input_string  # If start phrase not found, keep the string as is

    # Cut the end of the string that contains a number followed by "Embed"
    end_index = processed_string.rfind("Embed")
    if end_index != -1:
        processed_string = processed_string[:end_index].rstrip()

    return processed_string

def process_string(input_string):
    # Cut the beginning of the string till "Lyrics[Verse 1]\n"
    start_phrase = "Lyrics[Verse 1]\n"
    start_index = input_string.find(start_phrase)
    if start_index != -1:
        processed_string = input_string[start_index + len(start_phrase):]
    else:
        processed_string = input_string  # If start phrase not found, keep the string as is

    # Remove all instances of text enclosed in square brackets
    processed_string = re.sub(r"\[[^\]]*\]", "", processed_string)

    # Cut the end of the string that contains a number followed by "Embed"
    # Also removing the number before "Embed"
    end_index = processed_string.rfind("Embed")
    if end_index != -1:
        # Find the start of the number preceding "Embed"
        number_start = end_index
        while number_start > 0 and processed_string[number_start-1].isdigit():
            number_start -= 1
        processed_string = processed_string[:number_start].rstrip()

    return processed_string


result = process_string(song1.lyrics)
print(result)
# Out:
# When the morning came
# We were cleaning incense off your vinyl shelf
# 'Cause we lost track of time again
# Laughing with my feet in your lap
# Like you were my closest friend
# "How'd we end up on the floor, anyway?" you say
# "Your roommate's cheap-ass screw-top rosé, that's how"
# I see you every day now
#
#
# And I chose you
# The one I was dancing with
# In New York, no shoes
# Looked up at the sky and it was
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was
# The mark thеy saw on my collarbone
# The rust that grew bеtween telephones
# The lips I used to call home
# So scarlet, it was maroon
#
#
# When the silence came
# We were shaking, blind and hazy
# How the hell did we lose sight of us again?
# Sobbing with your head in your hands
# Ain't that the way shit always ends?
# You were standing hollow-eyed in the hallway
# Carnations you had thought were roses, that's us
# I feel you, no matter what
# The rubies that I gave up
# You might also like
# And I lost you
# The one I was dancing with
# In New York, no shoes
# Looked up at the sky and it was (Maroon)
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was (Maroon)
# The mark they saw on my collarbone
# The rust that grew between telephones
# The lips I used to call home
# So scarlet, it was maroon
#
#
# And I wake with your memory over me
# That's a real fucking legacy, legacy (It was maroon)
# And I wake with your memory over me
# That's a real fucking legacy to leave
#
#
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was maroon
# The mark they saw on my collarbone
# The rust that grew between telephones
# The lips I used to call home
# So scarlet, it was maroon
#
# It was maroon
# It was maroon

# %%
import pandas as pd
# Split the string into separate lines
lines = result.split('\n')

# Create a DataFrame with each line and its corresponding row number
df = pd.DataFrame({
    'Line': lines,
    'Row Number': range(1, len(lines) + 1)
})

df.head()  #
# Out:
#                                             Line  Row Number
# 0                          When the morning came           1
# 1  We were cleaning incense off your vinyl shelf           2
# 2             'Cause we lost track of time again           3
# 3              Laughing with my feet in your lap           4
# 4                Like you were my closest friend           5

# %%
print(song1.lyrics)
# Out:
# 135 ContributorsTranslationsEspañolTürkçeFrançais中文СрпскиItalianoMagyarPortuguêsNederlandsУкраїнськаDeutsch日本語SvenskaРусскийPolskiМонголMaroon Lyrics[Verse 1]
# When the morning came
# We were cleaning incense off your vinyl shelf
# 'Cause we lost track of time again
# Laughing with my feet in your lap
# Like you were my closest friend
# "How'd we end up on the floor, anyway?" you say
# "Your roommate's cheap-ass screw-top rosé, that's how"
# I see you every day now
#
# [Chorus]
# And I chose you
# The one I was dancing with
# In New York, no shoes
# Looked up at the sky and it was
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was
# The mark thеy saw on my collarbone
# The rust that grew bеtween telephones
# The lips I used to call home
# So scarlet, it was maroon
#
# [Verse 2]
# When the silence came
# We were shaking, blind and hazy
# How the hell did we lose sight of us again?
# Sobbing with your head in your hands
# Ain't that the way shit always ends?
# You were standing hollow-eyed in the hallway
# Carnations you had thought were roses, that's us
# I feel you, no matter what
# The rubies that I gave up
# You might also like[Chorus]
# And I lost you
# The one I was dancing with
# In New York, no shoes
# Looked up at the sky and it was (Maroon)
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was (Maroon)
# The mark they saw on my collarbone
# The rust that grew between telephones
# The lips I used to call home
# So scarlet, it was maroon
#
# [Bridge]
# And I wake with your memory over me
# That's a real fucking legacy, legacy (It was maroon)
# And I wake with your memory over me
# That's a real fucking legacy to leave
#
# [Chorus]
# The burgundy on my t-shirt
# When you splashed your wine into me
# And how the blood rushed into my cheeks
# So scarlet, it was maroon
# The mark they saw on my collarbone
# The rust that grew between telephones
# The lips I used to call home
# So scarlet, it was maroon
# [Outro]
# It was maroon
# It was maroon37Embed
